# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import sys
import requests

from PyQt5.QtWidgets import (
    QApplication,
    QLabel,
    QMainWindow,
    QWidget,
    QLineEdit,
    QFormLayout,
    QHBoxLayout,
    QPushButton,
    QGridLayout,
    QMessageBox,
    QMenuBar
    # QtCore, 
    # QtWidgets, 
    # QtGui
)

# %%
reso = pd.read_csv('data/resorts.csv')

# %%
reso.head()
# Out:
#              resort_name         state  summit    base  vertical  lifts  \
# 0  49(degrees) North, WA    Washington  5774.0  3923.0    1851.0    6.0
# 1         Afton Alps, MN     Minnesota   700.0   350.0     350.0   21.0
# 2     Alpine Meadows, CA    California  8673.0  6385.0    2288.0   13.0
# 3    Alpine Mountain, PA  Pennsylvania  1150.0   600.0     500.0    3.0
# 4      Alpine Valley, MI      Michigan  1210.0   910.0     300.0   14.0
#
#     runs  acres  green_percent  green_acres  blue_percent  blue_acres  \
# 0   68.0   2325           0.30       697.50          0.40      930.00
# 1   48.0    300           0.20        60.00          0.60      180.00
# 2  100.0   2400           0.25       600.00          0.40      960.00
# 3   21.0    120           0.17        20.40          0.55       66.00
# 4   25.0    118           0.39        46.02          0.26       30.68
#
#    black_percent  black_acres    lat     lon
# 0           0.30        697.5  49.00 -115.84
# ...

# %%
reso[ reso['state'] == 'Colorado']
# Out:
#              resort_name     state   summit     base  vertical  lifts   runs  \
# 14    Arapahoe Basin, CO  Colorado  13050.0  10780.0    2270.0    7.0  105.0
# 17   Aspen Highlands, CO  Colorado  11675.0   8040.0    3635.0    5.0  118.0
# 18          Aspen Mt, CO  Colorado  11212.0   7945.0    3267.0    8.0   76.0
# 27      Beaver Creek, CO  Colorado  11440.0   8100.0    3340.0   25.0  149.0
# 55      Breckenridge, CO  Colorado  12998.0   9600.0    3398.0   31.0  155.0
# 67        Buttermilk, CO  Colorado   9900.0   7870.0    2030.0    9.0   44.0
# 89         Copper Mt, CO  Colorado  12313.0   9712.0    2601.0   22.0  127.0
# 93     Crested Butte, CO  Colorado  12162.0   9375.0    2787.0   16.0  121.0
# 109           Eldora, CO  Colorado  10800.0   9200.0    1600.0   12.0   53.0
# 149         Keystone, CO  Colorado  12408.0   9280.0    3128.0   20.0  135.0
# 163         Loveland, CO  Colorado  13010.0  10800.0    2210.0   10.0   93.0
# ...

# %%
reso['green_acres']
# Out:
# 0      697.50
# 1       60.00
# 2      600.00
# 3       20.40
# 4       46.02
#         ...
# 359     38.50
# 360     39.60
# 361     33.00
# 362      5.00
# 363     18.00
# Name: green_acres, Length: 364, dtype: float64

# %%
# reso.set_index('resort_name')
# reso.plot(reso.loc[:0, ['green_percent', 'blue_percent', 'black_percent']])
# vail = reso[reso['resort_name'] == 'Vail, CO']
# plt.plot(vail['green_percent'], vail['blue_percent'])
ham = []
def finder(x):
    ham.append(reso.loc[reso['resort_name']==x, 'green_percent'].iloc[0] *100)
    ham.append(reso.loc[reso['resort_name']==x, 'blue_percent'].iloc[0] *100)
    ham.append(reso.loc[reso['resort_name']==x, 'black_percent'].iloc[0] *100)

# %%
finder('Vail, CO')
print(ham)
# Out:
# [18.0, 28.999999999999996, 53.0]

# %%
plt.pie(ham, labels=('Green Runs', 'Blue Runs', 'Black Runs'), colors=('green', 'blue', 'black'), autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa313a97040>,
# ...
#  [Text(0.928760704807937, 0.5894094953465411, 'Green Runs'),
#   Text(-0.4993895680663527, 0.9801071672559598, 'Blue Runs'),
#   Text(-0.10351925128402203, -1.0951181509835346, 'Black Runs')],
#  [Text(0.5065967480770565, 0.3214960883708406, '18.00%'),
#   Text(-0.2723943098543742, 0.5346039094123416, '29.00%'),
#   Text(-0.0564650461549211, -0.597337173263746, '53.00%')])

# %%
# !conda info
# Out:
#      active environment : myenv
#     active env location : /Users/Marc/miniconda3/envs/myenv
#             shell level : 2
#        user config file : /Users/Marc/.condarc
#  populated config files : /Users/Marc/.condarc
#           conda version : 4.9.2
#     conda-build version : not installed
#          python version : 3.8.5.final.0
#        virtual packages : __osx=10.15.5=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /Users/Marc/miniconda3  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /Users/Marc/miniconda3/pkgs
#                           /Users/Marc/.conda/pkgs
#        envs directories : /Users/Marc/miniconda3/envs
# ...

# %%
blah = reso[ reso['resort_name'] == 'Vail, CO']

# %%
blah[['green_percent', 'blue_percent', 'black_percent']].plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot([12,2,5,10])

# %%
reso_one = pd.read_csv('data/resorts.csv', index_col='resort_name')
reso_one.sort_values('green_acres', ascending=False, inplace=True)
reso_one["green_acres"].head(10).plot(kind='barh')
# reso_one['green_acres'].value_counts(ascending=True).head(10).plot(figsize=(20,20), kind='barh')
# Out:
# <AxesSubplot:ylabel='resort_name'>

# %%
reso_two = pd.read_csv('data/resorts.csv', index_col='resort_name')
reso_one = reso_two.head(5)
reso_one['green_percent'] = reso_one['green_percent']*100
reso_one['blue_percent'] = reso_one['blue_percent']*100
reso_one['black_percent'] = reso_one['black_percent']*100

greens = reso_one['green_percent'].head(5)
blues = reso_one['blue_percent'].head(5)
blacks = reso_one['black_acres'].head(5)
labels = [1,2,3,4,5]
width = .35


fig, ax = plt.subplots()

ax.bar(labels, greens, width, label="Percent Green")
ax.bar(labels, blues, width, label="Percent Blue", bottom=greens)
ax.bar(labels, blacks, width, label="Percent Black", bottom=blues+greens)
plt.show()

# %%
print(reso_one[['green_percent', 'blue_percent', 'black_percent']].head(5))
# Out:
#                        green_percent  blue_percent  black_percent
# resort_name
# 49(degrees) North, WA           30.0          40.0           30.0
# Afton Alps, MN                  20.0          60.0           20.0
# Alpine Meadows, CA              25.0          40.0           35.0
# Alpine Mountain, PA             17.0          55.0           28.0
# Alpine Valley, MI               39.0          26.0           35.0

# %%
reso_one[reso_one['summit'] == 5774.0].type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-9a6f27c5da79> in <module>
# ----> 1 reso_one[reso_one['summit'] == 5774.0].type()
#
# ~/miniconda3/envs/myenv/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
category_names = ['Strongly disagree', 'Disagree',
                  'Neither agree nor disagree', 'Agree', 'Strongly agree']
results = {
    'Question 1': [10, 15, 17, 32, 26],
    'Question 2': [26, 22, 29, 10, 13],
    'Question 3': [35, 37, 7, 2, 19],
    'Question 4': [32, 11, 9, 15, 33],
    'Question 5': [21, 29, 5, 5, 40],
    'Question 6': [8, 19, 5, 30, 38]
}

def survey(results, category_names):  
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.get_cmap('RdYlGn')(
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        ax.barh(labels, widths, left=starts, height=0.5,
                label=colname, color=color)
        xcenters = starts + widths / 2

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        for y, (x, c) in enumerate(zip(xcenters, widths)):
            ax.text(x, y, str(int(c)), ha='center', va='center',
                    color=text_color)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='small')

    return fig, ax


survey(results, category_names)
plt.show()

# %%
for key, value in reso_one.iterrows():
    # print(key, value['green_percent'], value['blue_percent'], value['black_percent'])

    greens = value['green_percent']
    blues = value['blue_percent']
    blacks = value['black_percent']

    fig, ax = plt.subplots()
    ax.bar(key, greens, width, label="Percent Green")
    ax.bar(key, blues, width, label="Percent Blue", bottom=greens)
    ax.bar(key, blacks, width, label="Percent Black", bottom=blues+greens)


    # labels = [1,2,3,4,5]
    width = .35

plt.show()

# %%
reso_one
# Out:
#                               state  summit    base  vertical  lifts   runs  \
# resort_name
# 49(degrees) North, WA    Washington  5774.0  3923.0    1851.0    6.0   68.0
# Afton Alps, MN            Minnesota   700.0   350.0     350.0   21.0   48.0
# Alpine Meadows, CA       California  8673.0  6385.0    2288.0   13.0  100.0
# Alpine Mountain, PA    Pennsylvania  1150.0   600.0     500.0    3.0   21.0
# Alpine Valley, MI          Michigan  1210.0   910.0     300.0   14.0   25.0
#
#                        acres  green_percent  green_acres  blue_percent  \
# resort_name
# 49(degrees) North, WA   2325           30.0       697.50          40.0
# Afton Alps, MN           300           20.0        60.00          60.0
# Alpine Meadows, CA      2400           25.0       600.00          40.0
# Alpine Mountain, PA      120           17.0        20.40          55.0
# Alpine Valley, MI        118           39.0        46.02          26.0
#
# ...

# %%
for key, value in reso_one[['green_percent', 'blue_percent', 'black_percent']].iteritems():
    print(key,value)
# Out:
# green_percent resort_name
# 49(degrees) North, WA    30.0
# Afton Alps, MN           20.0
# Alpine Meadows, CA       25.0
# Alpine Mountain, PA      17.0
# Alpine Valley, MI        39.0
# Name: green_percent, dtype: float64
# blue_percent resort_name
# 49(degrees) North, WA    40.0
# Afton Alps, MN           60.0
# Alpine Meadows, CA       40.0
# Alpine Mountain, PA      55.0
# Alpine Valley, MI        26.0
# Name: blue_percent, dtype: float64
# black_percent resort_name
# 49(degrees) North, WA    30.0
# Afton Alps, MN           20.0
# Alpine Meadows, CA       35.0
# Alpine Mountain, PA      28.0
# Alpine Valley, MI        35.0
# Name: black_percent, dtype: float64

# %%
reso_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 49(degrees) North, WA to Alpine Valley, MI
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          5 non-null      object
#  1   summit         5 non-null      float64
#  2   base           5 non-null      float64
#  3   vertical       5 non-null      float64
#  4   lifts          5 non-null      float64
#  5   runs           5 non-null      float64
#  6   acres          5 non-null      int64
#  7   green_percent  5 non-null      float64
#  8   green_acres    5 non-null      float64
#  9   blue_percent   5 non-null      float64
#  10  blue_acres     5 non-null      float64
#  11  black_percent  5 non-null      float64
#  12  black_acres    5 non-null      float64
#  13  lat            5 non-null      float64
#  14  lon            5 non-null      float64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 812.0+ bytes

# %%
reso_two = pd.read_csv('data/resorts.csv', index_col='resort_name')
reso_one = reso_two.head(5)
reso_one['green_percent'] = reso_one['green_percent']*100
reso_one['blue_percent'] = reso_one['blue_percent']*100
reso_one['black_percent'] = reso_one['black_percent']*100

greens = reso_one['green_percent']
blues = reso_one['blue_percent']
blacks = reso_one['black_acres']
labels = [1,2,3,4,5]
width = .35


fig, ax = plt.subplots()

ax.bar(labels, greens, width, label="Percent Green")
ax.bar(labels, blues, width, label="Percent Blue", bottom=greens)
ax.bar(labels, blacks, width, label="Percent Black", bottom=blues+greens)
plt.show()

# %%
print(reso_one.get('summit'))
# Out:
# resort_name
# 49(degrees) North, WA    5774.0
# Afton Alps, MN            700.0
# Alpine Meadows, CA       8673.0
# Alpine Mountain, PA      1150.0
# Alpine Valley, MI        1210.0
# Name: summit, dtype: float64

# %%
class Window(QMainWindow):

    def __init__(self):
        # super().__init__()
        QMainWindow.__init__(self)

        # form layout for the elements
        self.form_elements_layout = QFormLayout()

        # here we are creating the elements. Qlabel is the goes to the left and is the label, Qlineedit is the input field
        self.label_loan = QLabel("Principal loan amount")
        self.edit_loan = QLineEdit()


        self.label_interest = QLabel("Yearly interest rate (%)")
        self.edit_interest = QLineEdit()

        self.label_period = QLabel("Period in months")
        self.edit_period = QLineEdit()

        self.label_payment = QLabel("Monthly payment")
        self.total_payment = QLineEdit()
        self.total_payment.setReadOnly(True)


        # adding form elelments to the QFormLayout
        self.form_elements_layout.addRow(self.label_loan, self.edit_loan)
        self.form_elements_layout.addRow(self.label_interest, self.edit_interest)
        self.form_elements_layout.addRow(self.label_period, self.edit_period)
        self.form_elements_layout.addRow(self.label_payment, self.total_payment)


        # creating buttons
        self.button_calculate = QPushButton("Calculate")
        self.button_clear = QPushButton("Clear")
        # add button actions
        self.button_calculate.clicked.connect(self.on_button_calculate_click)
        self.button_clear.clicked.connect(self.on_button_clear_clicked)

        # Layout for buttons. H box layout just means side by side
        self.action_button_layout = QHBoxLayout()
        self.action_button_layout.addWidget(self.button_calculate)
        self.action_button_layout.addWidget(self.button_clear)



        #  the main layout to attach form elements and the buttons
        self.main_layout = QGridLayout()
        # we are adding the form layout to the first row(0), first column(0)
        self.main_layout.addLayout(self.form_elements_layout, 0, 0)
        self.main_layout.addLayout(self.action_button_layout, 1, 0)


        widget = QWidget()
        widget.setLayout(self.main_layout)
        self.setCentralWidget(widget)
        # Set a fixed size of the app window
        self.setFixedSize(500,200)





    def on_button_calculate_click(self):
        # here we are just error handling if no inputs are there otherwise it will crash
        if self.edit_loan.text() == "" or self.edit_interest.text() == "" or self.edit_period.text() == "":
            # alert box. Needs self becasue its a class, then the messagage box title, then the message you want
            QMessageBox.about(self, "Missing Values", "Principal loan amouunt, yearly interest reate or period in months is empty")

        else:
            # .text() is the value from the input
            loan = float(self.edit_loan.text())
            interest = float(self.edit_interest.text())
            interest_per_month = interest / (12 * 100)
            period = float(self.edit_period.text())
            emi = (loan * interest_per_month * (1 + interest_per_month) ** period) / ( (1 + interest_per_month) ** period - 1)
            self.total_payment.setText(str(round(emi,2)))
            print(self.total_payment)

    def on_button_clear_clicked(self):
        self.edit_loan.setText(self.edit_loan.clear())
        self.edit_interest.setText(self.edit_interest.clear())
        self.edit_period.setText(self.edit_period.clear())
        self.total_payment.setText(self.total_payment.clear())



def main(args):
    app = QApplication(args)

    application = Window()
    application.setWindowTitle("EMI Cal")
    application.show()

    # kill the window instance (kill the pid when the window is closed so it doesn't run in the background)
    app.exec_()


if __name__ == '__main__':
    main(sys.argv)

# %%
# from PyQt5 import QtCore, QtWidgets

from matplotlib.backends.backend_qt5agg import FigureCanvasQTAgg
from matplotlib.figure import Figure

reso_two = pd.read_csv('data/resorts.csv', index_col='resort_name')
reso_one = reso_two.head(5)


class MplCanvas(FigureCanvasQTAgg):

    def __init__(self, parent=None, width=5, height=4, dpi=100):
        fig = Figure(figsize=(width, height), dpi=dpi)
        self.axes = fig.add_subplot(111)
        super(MplCanvas, self).__init__(fig)


class MainWindow(QtWidgets.QMainWindow):

    def __init__(self, *args, **kwargs):
        reso_one.sort_values('green_acres', ascending=False, inplace=True)

        super(MainWindow, self).__init__(*args, **kwargs)

        # Create the maptlotlib FigureCanvas object, 
        # which defines a single set of axes as self.axes.
        sc = MplCanvas(self, width=5, height=4, dpi=100)
        sc.axes.plot(reso_one["green_acres"])
        self.setCentralWidget(sc)

        self.show()


app = QtWidgets.QApplication(sys.argv)
w = MainWindow()
app.exec_()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6c55d55eb727> in <module>
#      16
#      17
# ---> 18 class MainWindow(QtWidgets.QMainWindow):
#      19
#      20     def __init__(self, *args, **kwargs):
#
# NameError: name 'QtWidgets' is not defined

# %%
import sys
# from PySide6.QtWidgets import QApplication, QPushButton
from PyQt5.QtCore import Slot

@Slot()
def say_hello():
 print("Button clicked, Hello!")

# Create the Qt Application
app = QApplication(sys.argv)
# Create a button, connect it and show it
button = QPushButton("Click me")
button.clicked.connect(say_hello)
button.show()
# Run the main Qt loop
app.exec_()
# Out:
# Button clicked, Hello!
# Button clicked, Hello!

# %%
from PyQt5.QtWidgets import (QLineEdit, QPushButton, QApplication,
    QVBoxLayout, QDialog)

class Form(QDialog):

    def __init__(self, parent=None):
        super(Form, self).__init__(parent)
        # Create widgets
        self.edit = QLineEdit("Write my name here")
        self.button = QPushButton("Show Greetings")
        # Create layout and add widgets
        layout = QVBoxLayout()
        layout.addWidget(self.edit)
        layout.addWidget(self.button)
        # Set dialog layout
        self.setLayout(layout)
        # Add button signal to greetings slot
        self.button.clicked.connect(self.greetings)

    # Greets the user
    def greetings(self):
        print ("Hello %s" % self.edit.text())

if __name__ == '__main__':
    # Create the Qt Application
    app = QApplication(sys.argv)
    # Create and show the form
    form = Form()
    form.show()
    # Run the main Qt loop
    sys.exit(app.exec_())
# Out:
# Hello sdfsdf
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
from PyQt5.QtCore import *

from MainWindow import Ui_MainWindow

from datetime import datetime
import json
import os
import sys
from urllib.parse import urlencode

OPENWEATHERMAP_API_KEY = os.environ.get('0c03ffa975e1897ad56737b33c730823')

"""
Get an API key from https://openweathermap.org/ to use with this
application.
"""


def from_ts_to_time_of_day(ts):
    dt = datetime.fromtimestamp(ts)
    return dt.strftime("%I%p").lstrip("0")


class WorkerSignals(QObject):
    '''
    Defines the signals available from a running worker thread.
    '''
    finished = pyqtSignal()
    error = pyqtSignal(str)
    result = pyqtSignal(dict, dict)

class WeatherWorker(QRunnable):
    '''
    Worker thread for weather updates.
    '''
    signals = WorkerSignals()
    is_interrupted = False

    def __init__(self, location):
        super(WeatherWorker, self).__init__()
        self.location = location

    @pyqtSlot()
    def run(self):
        try:
            params = dict(
                q=self.location,
                appid=OPENWEATHERMAP_API_KEY
            )

            url = 'http://api.openweathermap.org/data/2.5/weather?%s&units=metric' % urlencode(params)
            r = requests.get(url)
            weather = json.loads(r.text)

            # Check if we had a failure (the forecast will fail in the same way).
            if weather['cod'] != 200:
                raise Exception(weather['message'])

            url = 'http://api.openweathermap.org/data/2.5/forecast?%s&units=metric' % urlencode(params)
            r = requests.get(url)
            forecast = json.loads(r.text)

            self.signals.result.emit(weather, forecast)

        except Exception as e:
            self.signals.error.emit(str(e))

        self.signals.finished.emit()



class MainWindow(QMainWindow, Ui_MainWindow):

    def __init__(self, *args, **kwargs):
        super(MainWindow, self).__init__(*args, **kwargs)
        self.setupUi(self)

        self.pushButton.pressed.connect(self.update_weather)

        self.threadpool = QThreadPool()

        self.show()


    def alert(self, message):
        alert = QMessageBox.warning(self, "Warning", message)

    def update_weather(self):
        worker = WeatherWorker(self.lineEdit.text())
        worker.signals.result.connect(self.weather_result)
        worker.signals.error.connect(self.alert)
        self.threadpool.start(worker)

    def weather_result(self, weather, forecasts):
        self.latitudeLabel.setText("%.2f °" % weather['coord']['lat'])
        self.longitudeLabel.setText("%.2f °" % weather['coord']['lon'])

        self.windLabel.setText("%.2f m/s" % weather['wind']['speed'])

        self.temperatureLabel.setText("%.1f °C" % weather['main']['temp'])
        self.pressureLabel.setText("%d" % weather['main']['pressure'])
        self.humidityLabel.setText("%d" % weather['main']['humidity'])

        self.sunriseLabel.setText(from_ts_to_time_of_day(weather['sys']['sunrise']))

        self.weatherLabel.setText("%s (%s)" % (
            weather['weather'][0]['main'],
            weather['weather'][0]['description']
        )
                                  )

        self.set_weather_icon(self.weatherIcon, weather['weather'])

        for n, forecast in enumerate(forecasts['list'][:5], 1):
            getattr(self, 'forecastTime%d' % n).setText(from_ts_to_time_of_day(forecast['dt']))
            self.set_weather_icon(getattr(self, 'forecastIcon%d' % n), forecast['weather'])
            getattr(self, 'forecastTemp%d' % n).setText("%.1f °C" % forecast['main']['temp'])

    def set_weather_icon(self, label, weather):
        label.setPixmap(
            QPixmap(os.path.join('images', "%s.png" %
                                 weather[0]['icon']
                                 )
                    )

        )


if __name__ == '__main__':

    app = QApplication([])
    window = MainWindow()
    app.exec_()
